# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/twitter-bullbear/verysmol.csv

# %% [markdown]
# Базовая модель - сентимент классифаер, обученный на твиттах
# 3 сентимента - положительный(label_2), нейтральный(label_1), негативный(label_0)
#
# Датасет - заголовки с новостного сайта, каждый размечен на положительный/негативный. С помощью него можно real-time мониторить ситуацию на рынке и привязать к нему торгового бота. Из-за ограничений API получилось спарсить только 400 заголовков.

# %%
from transformers import (
    AutoModelForSequenceClassification,
    TFAutoModelForSequenceClassification,
    AutoTokenizer,
    AutoConfig,
    Trainer,
    TrainingArguments,
)

import random
import csv
import urllib.request
from scipy.special import softmax
from sklearn.model_selection import train_test_split
import torch

# %%
def set_seed(seed):
    torch.manual_seed(seed)
    random.seed(seed)
    np.random.seed(seed)
set_seed(0)

# %%
df = pd.read_csv('/kaggle/input/twitter-bullbear/verysmol.csv', sep=';')
df.head()
# Out:
#    Unnamed: 0   target                                              title  \
# 0           0  bearish  Founder of Crypto Capital Venture: $ADA and $X...
# 1           1  bearish  Cardano’s Steady Progress: Foundation CEO Fred...
# 2           2  bearish  ChatGPT predicts price of Cardano for start of...
# 3           3  bearish  FTX Moves $316 Million Crypto to Different Exc...
# 4           4  bearish  Cardano upgrade delays tied to ‘boring’ academ...
#
#               source          currencies  \
# 0    cryptoglobe.com  ['XRP', 'Cardano']
# 1    cryptoglobe.com         ['Cardano']
# 2        finbold.com         ['Cardano']
# 3    coinpaprika.com          ['Solana']
# 4  cointelegraph.com         ['Cardano']
#
#                                                  url                  date
# 0  https://cryptopanic.com/news/19025185/Founder-...  2023-11-08T19:29:48Z
# 1  https://cryptopanic.com/news/19025145/Cardanos...  2023-11-08T19:07:29Z
# 2  https://cryptopanic.com/news/19024549/ChatGPT-...  2023-11-08T15:16:20Z
# 3  https://cryptopanic.com/news/19023693/FTX-Move...  2023-11-08T10:37:04Z
# 4  https://cryptopanic.com/news/19023555/Cardano-...  2023-11-08T09:46:00Z

# %%
task = 'sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"

tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/747 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
model.save_pretrained(MODEL)

text = df.title.iloc[0]
text = preprocess(text)
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
scores = output[0][0].detach().numpy()
scores = softmax(scores)

# Print labels and scores
ranking = np.argsort(scores)
ranking = ranking[::-1]
for i in range(scores.shape[0]):
    l = config.id2label[ranking[i]]
    s = scores[ranking[i]]
    print(f"{i+1}) {l} {np.round(float(s), 4)}")
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# 1) LABEL_1 0.6496
# 2) LABEL_2 0.3446
# 3) LABEL_0 0.0058

# %% [markdown]
# Видим, что изначальная модель плохо реагирует на новый вид разметки.

# %%
df['target'] = df['target'].map({'bearish': 0, 'bullish': 1})
df = df.drop(index=0, axis=0)
dataset = df[['target', 'title']].rename(columns={'target': 'label', 'title': 'text'})
dataset.head()
# Out:
#    label                                               text
# 1      0  Cardano’s Steady Progress: Foundation CEO Fred...
# 2      0  ChatGPT predicts price of Cardano for start of...
# 3      0  FTX Moves $316 Million Crypto to Different Exc...
# 4      0  Cardano upgrade delays tied to ‘boring’ academ...
# 5      0  Should Cardano holders be prepared for a price...

# %%
text = dataset['text'].tolist()
label = dataset['label'].tolist()

train_texts, val_texts, train_labels, val_labels = train_test_split(text, label, test_size=.2)

train_encodings = tokenizer(train_texts, truncation=True, padding=True)
val_encodings = tokenizer(val_texts, truncation=True, padding=True)

# %%
class smolDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_dataset = smolDataset(train_encodings, train_labels)
val_dataset = smolDataset(val_encodings, val_labels)

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=10, # т.к. датасет очень маленький, то решил, что нет смысла ставить >10 эпох
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='200' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [200/200 11:26, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.416300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.194100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.220900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.251300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.240100</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.205800</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.193500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.157000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.189100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.088300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.116100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.247600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.126100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.195700</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.074900</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.200400</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.099300</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.265600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.085600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.235200</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=200, training_loss=0.19013698309659957, metrics={'train_runtime': 690.3193, 'train_samples_per_second': 4.621, 'train_steps_per_second': 0.29, 'total_flos': 60654837293820.0, 'train_loss': 0.19013698309659957, 'epoch': 10.0})

# %%
from datasets import load_dataset
dataset = load_dataset("yelp_review_full")
type(dataset)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# datasets.dataset_dict.DatasetDict

# %%
text = df.title.iloc[0]
text = preprocess(text)
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
scores = output[0][0].detach().numpy()
scores = softmax(scores)

ranking = np.argsort(scores)
ranking = ranking[::-1]
for i in range(scores.shape[0]):
    l = config.id2label[ranking[i]]
    s = scores[ranking[i]]
    print(f"{i+1}) {l} {np.round(float(s), 4)}")
# Out:
# 1) LABEL_0 0.9636
# 2) LABEL_1 0.0347
# 3) LABEL_2 0.0017

# %% [markdown]
# Теперь видим, что все работает прекрасно. 0-я строка не была в датасете, поэтому проверка на нем является достаточно корректной, больше строк из датасета решил не убирать, т.к. он изначально очень маленький.
